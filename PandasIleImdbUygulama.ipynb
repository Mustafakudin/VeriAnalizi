# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Imdb-upt.CSV")

# %%
df
# Out:
#       Unnamed: 0                           title  \
# 0              0                        Ad Astra
# 1              1                       Bloodshot
# 2              2               Bad Boys for Life
# 3              3                         Ant-Man
# 4              4  Percy Jackson: Sea of Monsters
# ...          ...                             ...
# 9995        9995                           Cargo
# 9996        9996                  The Good Night
# 9997        9997              The World Is Yours
# 9998        9998             The Grand Seduction
# 9999        9999        Woochi: The Demon Slayer
#
#                                                overview original_language  \
# 0     The near future, a time when both hope and har...                en
# 1     After he and his wife are murdered, marine Ray...                en
# 2     Marcus and Mike are forced to confront new thr...                en
# 3     Armed with the astonishing ability to shrink i...                en
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                           title  \
# 0           0                        Ad Astra
# 1           1                       Bloodshot
# 2           2               Bad Boys for Life
# 3           3                         Ant-Man
# 4           4  Percy Jackson: Sea of Monsters
#
#                                             overview original_language  \
# 0  The near future, a time when both hope and har...                en
# 1  After he and his wife are murdered, marine Ray...                en
# 2  Marcus and Mike are forced to confront new thr...                en
# 3  Armed with the astonishing ability to shrink i...                en
# 4  In their quest to confront the ultimate evil, ...                en
#
#    vote_count  vote_average
# 0        2853           5.9
# 1        1349           7.2
# 2        2530           7.1
# 3       13611           7.1
# 4        3542           5.9

# %%
df.head(10)
# Out:
#    Unnamed: 0                                              title  \
# 0           0                                           Ad Astra
# 1           1                                          Bloodshot
# 2           2                                  Bad Boys for Life
# 3           3                                            Ant-Man
# 4           4                     Percy Jackson: Sea of Monsters
# 5           5  Birds of Prey (and the Fantabulous Emancipatio...
# 6           6                              Live Free or Die Hard
# 7           7                                         Cold Blood
# 8           8                                         Underwater
# 9           9                                       The Platform
#
#                                             overview original_language  \
# 0  The near future, a time when both hope and har...                en
# 1  After he and his wife are murdered, marine Ray...                en
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0                     title  \
# 9995        9995                     Cargo
# 9996        9996            The Good Night
# 9997        9997        The World Is Yours
# 9998        9998       The Grand Seduction
# 9999        9999  Woochi: The Demon Slayer
#
#                                                overview original_language  \
# 9995  The story of CARGO takes place on rusty space-...                de
# 9996  Gary, a musician, is trapped in an unhappy rel...                en
# 9997  To escape his life of crime, a Paris drug deal...                fr
# 9998  A small fishing village must procure a local d...                en
# 9999  Spanning four centuries in Korea, this epic ac...                ko
#
#       vote_count  vote_average
# 9995         225           5.9
# 9996          67           5.6
# 9997         234           7.1
# 9998         169           6.7
# 9999          78           6.7

# %%
df.tail(10)
# Out:
#       Unnamed: 0                         title  \
# 9990        9990               Attack on Titan
# 9991        9991  Pokémon: The Rise of Darkrai
# 9992        9992                Eagle vs Shark
# 9993        9993              High Flying Bird
# 9994        9994                       Zapped!
# 9995        9995                         Cargo
# 9996        9996                The Good Night
# 9997        9997            The World Is Yours
# 9998        9998           The Grand Seduction
# 9999        9999      Woochi: The Demon Slayer
#
#                                                overview original_language  \
# 9990  100 years ago, titans suddenly appeared on Ear...                ja
# 9991  Ash and friends (this time accompanied by newc...                ja
# 9992  The New Zealand made "Eagle vs Shark" is the t...                en
# 9993  During an NBA lockout, a sports agent, Ray Bur...                en
# ...

# %%
df["title"]
# Out:
# 0                             Ad Astra
# 1                            Bloodshot
# 2                    Bad Boys for Life
# 3                              Ant-Man
# 4       Percy Jackson: Sea of Monsters
#                      ...
# 9995                             Cargo
# 9996                    The Good Night
# 9997                The World Is Yours
# 9998               The Grand Seduction
# 9999          Woochi: The Demon Slayer
# Name: title, Length: 10000, dtype: object

# %%
df["title"].head()
# Out:
# 0                          Ad Astra
# 1                         Bloodshot
# 2                 Bad Boys for Life
# 3                           Ant-Man
# 4    Percy Jackson: Sea of Monsters
# Name: title, dtype: object

# %%
df
# Out:
#       Unnamed: 0                           title  \
# 0              0                        Ad Astra
# 1              1                       Bloodshot
# 2              2               Bad Boys for Life
# 3              3                         Ant-Man
# 4              4  Percy Jackson: Sea of Monsters
# ...          ...                             ...
# 9995        9995                           Cargo
# 9996        9996                  The Good Night
# 9997        9997              The World Is Yours
# 9998        9998             The Grand Seduction
# 9999        9999        Woochi: The Demon Slayer
#
#                                                overview original_language  \
# 0     The near future, a time when both hope and har...                en
# 1     After he and his wife are murdered, marine Ray...                en
# 2     Marcus and Mike are forced to confront new thr...                en
# 3     Armed with the astonishing ability to shrink i...                en
# ...

# %%
df[["title","vote_average"]].head()
# Out:
#                             title  vote_average
# 0                        Ad Astra           5.9
# 1                       Bloodshot           7.2
# 2               Bad Boys for Life           7.1
# 3                         Ant-Man           7.1
# 4  Percy Jackson: Sea of Monsters           5.9

# %%
df[["title","vote_average"]].tail(7)
# Out:
#                          title  vote_average
# 9993          High Flying Bird           5.8
# 9994                   Zapped!           5.2
# 9995                     Cargo           5.9
# 9996            The Good Night           5.6
# 9997        The World Is Yours           7.1
# 9998       The Grand Seduction           6.7
# 9999  Woochi: The Demon Slayer           6.7

# %%
df[5:10][["title","vote_average"]]
# Out:
#                                                title  vote_average
# 5  Birds of Prey (and the Fantabulous Emancipatio...           7.1
# 6                              Live Free or Die Hard           6.5
# 7                                         Cold Blood           5.1
# 8                                         Underwater           6.5
# 9                                       The Platform           7.2

# %%
df
# Out:
#       Unnamed: 0                           title  \
# 0              0                        Ad Astra
# 1              1                       Bloodshot
# 2              2               Bad Boys for Life
# 3              3                         Ant-Man
# 4              4  Percy Jackson: Sea of Monsters
# ...          ...                             ...
# 9995        9995                           Cargo
# 9996        9996                  The Good Night
# 9997        9997              The World Is Yours
# 9998        9998             The Grand Seduction
# 9999        9999        Woochi: The Demon Slayer
#
#                                                overview original_language  \
# 0     The near future, a time when both hope and har...                en
# 1     After he and his wife are murdered, marine Ray...                en
# 2     Marcus and Mike are forced to confront new thr...                en
# 3     Armed with the astonishing ability to shrink i...                en
# ...

# %%
df[df["vote_average"]>8.0].head(50)
# Out:
#      Unnamed: 0                                              title  \
# 21           21                                              Joker
# 22           22                              Miracle in Cell No. 7
# 25           25                                           Parasite
# 30           30       Harry Potter and the Deathly Hallows: Part 2
# 37           37                                  Trolls World Tour
# 47           47                                       Interstellar
# 54           54                                         Just Mercy
# 63           63                             Avengers: Infinity War
# 64           64                                          Star Wars
# 75           75                                  Avengers: Endgame
# 79           79                                        Jojo Rabbit
# 80           80                                          Inception
# 88           88                                    The Dark Knight
# ...

# %%
df
# Out:
#       Unnamed: 0                           title  \
# 0              0                        Ad Astra
# 1              1                       Bloodshot
# 2              2               Bad Boys for Life
# 3              3                         Ant-Man
# 4              4  Percy Jackson: Sea of Monsters
# ...          ...                             ...
# 9995        9995                           Cargo
# 9996        9996                  The Good Night
# 9997        9997              The World Is Yours
# 9998        9998             The Grand Seduction
# 9999        9999        Woochi: The Demon Slayer
#
#                                                overview original_language  \
# 0     The near future, a time when both hope and har...                en
# 1     After he and his wife are murdered, marine Ray...                en
# 2     Marcus and Mike are forced to confront new thr...                en
# 3     Armed with the astonishing ability to shrink i...                en
# ...

# %%
df[df["vote_count"]>10000][df["vote_average"]>8]
# Out:
# C:\Users\Mustafa\AppData\Local\Temp/ipykernel_16216/4022324008.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df["vote_count"]>10000][df["vote_average"]>8]
#      Unnamed: 0                                              title  \
# 21           21                                              Joker
# 30           30       Harry Potter and the Deathly Hallows: Part 2
# 47           47                                       Interstellar
# 63           63                             Avengers: Infinity War
# 64           64                                          Star Wars
# 75           75                                  Avengers: Endgame
# 80           80                                          Inception
# 88           88                                    The Dark Knight
# 96           96                           The Shawshank Redemption
# 110         110                                      The Godfather
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# title                 0
# overview             30
# original_language     0
# vote_count            0
# vote_average          0
# dtype: int64

# %%
df.dropna()
# Out:
#       Unnamed: 0                           title  \
# 0              0                        Ad Astra
# 1              1                       Bloodshot
# 2              2               Bad Boys for Life
# 3              3                         Ant-Man
# 4              4  Percy Jackson: Sea of Monsters
# ...          ...                             ...
# 9995        9995                           Cargo
# 9996        9996                  The Good Night
# 9997        9997              The World Is Yours
# 9998        9998             The Grand Seduction
# 9999        9999        Woochi: The Demon Slayer
#
#                                                overview original_language  \
# 0     The near future, a time when both hope and har...                en
# 1     After he and his wife are murdered, marine Ray...                en
# 2     Marcus and Mike are forced to confront new thr...                en
# 3     Armed with the astonishing ability to shrink i...                en
# ...

# %%
result=len(df.index)  # toplam kayıtı ogrenmek istersek

# %%
result
# Out:
# 10000

# %%
## Ortalama maas sorsaydı df["salary"].means() boyle bir cevap veriridin

# %%
df["index"].means()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# The above exception was the direct cause of the following exception:
#
# ...
